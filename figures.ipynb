# %% [markdown]
# ## Figures

# %%
# imports
import pandas as pd; pd.set_option('display.max_columns', None)
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats
import figures.figures as figures

# formatting parameters
plt.rcParams['axes.labelsize'] = 12
plt.rcParams['xtick.labelsize'] = 10
plt.rcParams['ytick.labelsize'] = 10

# %% [markdown]
# #### Phonetic Clustering Scores

# %%
pcs_v1_data_bsa = pd.read_csv('analyses/dataframes/pcs_v1_data_bsa.csv')
figures.plot_pcs_v1(pcs_v1_data_bsa)

# %%
pcs_v2_data_bsa = pd.read_csv('analyses/dataframes/pcs_v2_data_bsa.csv')
figures.plot_pcs_v2(pcs_v2_data_bsa)

# %% [markdown]
# #### Correlation of Phonetic Clustering Scores

# %%
pcs_corrs_bsa = pd.read_csv('statistics/dataframes/pcs_corrs_bsa.csv')
figures.plot_pcs_correlations(pcs_corrs_bsa)

# %% [markdown]
# #### Phonetic-CRL

# %%
psim_crl_v1_data_bsa = pd.read_csv('analyses/dataframes/psim_crl_v1_data_bsa.csv')
figures.plot_psim_crl_v1(psim_crl_v1_data_bsa)

# %%
psim_crl_v2_data_bsa = pd.read_csv('analyses/dataframes/psim_crl_v2_data_bsa.csv')
figures.plot_psim_crl_v2(psim_crl_v2_data_bsa)

# %% [markdown]
# #### Phonetic Intrusions

# %%
psim_intr_v1_data_bsa = pd.read_csv('analyses/dataframes/psim_intr_v1_data_bsa.csv')
figures.plot_psim_intr_v1(psim_intr_v1_data_bsa)

# %%
psim_intr_v2_data_bsa = pd.read_csv('analyses/dataframes/psim_intr_v2_data_bsa.csv')
figures.plot_psim_intr_v2(psim_intr_v2_data_bsa)

# %% [markdown]
# #### First Phoneme Recall Probability

# %%
ph1_recall_data_bsa = pd.read_csv('analyses/dataframes/ph1_recall_data_bsa.csv')
figures.plot_ph1_recall(ph1_recall_data_bsa, 3)
# Out:
# /home1/hherrema/research_projects/pho_sim_fr/figures/figures.py:173: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_intrac = df_intrac.groupby('ph1')['p_recall'].mean().reset_index()
# /home1/hherrema/research_projects/pho_sim_fr/figures/figures.py:174: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   avg_scalp = df_scalp.groupby('ph1')['p_recall'].mean().reset_index()

# %% [markdown]
# #### Temporal Clustering Score

# %%
tcs_data_bsa = pd.read_csv('analyses/dataframes/tcs_data_bsa.csv')
figures.plot_tcs(tcs_data_bsa)

# %% [markdown]
# #### Semantic Clustering Score

# %%
scs_data_bsa = pd.read_csv('analyses/dataframes/scs_data_bsa.csv')
figures.plot_scs(scs_data_bsa)

# %% [markdown]
# #### Correlations with Recall Probability

# %%
p_recall_corrs_bsa = pd.read_csv('statistics/dataframes/p_recall_corrs_bsa.csv')
figures.plot_p_recall_correlations(p_recall_corrs_bsa)
